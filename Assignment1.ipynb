# %% [markdown]
# Task 1

# %%
a = 'Good Morning'
print(a.upper())
# Out:
# GOOD MORNING

# %% [markdown]
# upper : to make all the alphabets in Capital letter

# %%
print(a.lower())
# Out:
# good morning

# %% [markdown]
# lower : to make all the alphabets in smaller letter

# %%
print(a.startswith('G'))
# Out:
# True

# %%
print(a.endswith('s'))
# Out:
# False

# %%
print(a.capitalize())
# Out:
# Good morning

# %% [markdown]
# Capitalize : to make the first alphabet in capital letter

# %%
print(a)
# Out:
# Good Morning

# %%
sentence = "welcome to home"
word = "to"
'to' in sentence
# Out:
# True

# %% [markdown]
# TASK 2

# %%
str1 = 'Welcome to python'
'to' in str1
# Out:
# True
